# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

# %%
car = pd.read_csv('cars.csv')

# %%
car.head(5)
# Out:
#                          Car   MPG  Cylinders  Displacement  Horsepower  \
# 0  Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1          Buick Skylark 320  15.0          8         350.0       165.0
# 2         Plymouth Satellite  18.0          8         318.0       150.0
# 3              AMC Rebel SST  16.0          8         304.0       150.0
# 4                Ford Torino  17.0          8         302.0       140.0
#
#    Weight  Acceleration  Model Origin
# 0  3504.0          12.0     70     US
# 1  3693.0          11.5     70     US
# 2  3436.0          11.0     70     US
# 3  3433.0          12.0     70     US
# 4  3449.0          10.5     70     US

# %%
car.Origin.unique()
# Out:
# array(['US', 'Europe', 'Japan'], dtype=object)

# %%
car.dtypes
# Out:
# Car              object
# MPG             float64
# Cylinders         int64
# Displacement    float64
# Horsepower      float64
# Weight          float64
# Acceleration    float64
# Model             int64
# Origin           object
# dtype: object

# %%
car.Cylinders.unique()
# Out:
# array([8, 4, 6, 3, 5], dtype=int64)

# %%
car.Model.unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82], dtype=int64)

# %%
car.Origin.value_counts()
# Out:
# US        254
# Japan      79
# Europe     73
# Name: Origin, dtype: int64

# %%
car.isnull().sum()
# Out:
# Car             0
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model           0
# Origin          0
# dtype: int64

# %%
plt.figure(figsize=(15,10))
car.Origin.value_counts().plot(kind='pie')

# %%
plt.figure(figsize=(10, 5))
sn.distplot(car['Weight'],kde=True,color='green')

# %%
plt.figure(figsize=(10,5))
sn.boxplot(car['Weight'])

# %%
car.Model.value_counts()
# Out:
# 73    40
# 78    36
# 70    35
# 76    34
# 82    31
# 81    30
# 75    30
# 80    29
# 79    29
# 71    29
# 77    28
# 72    28
# 74    27
# Name: Model, dtype: int64

# %%
plt.figure(figsize=(15,8))
sn.countplot(x='Model',data=car,hue='Origin')

# %%
plt.figure(figsize=(10,5))
sn.boxplot(car['Model'])

# %%
car.Cylinders.value_counts()
# Out:
# 4    207
# 8    108
# 6     84
# 3      4
# 5      3
# Name: Cylinders, dtype: int64

# %%
plt.figure(figsize=(5,5))
sn.countplot(x='Cylinders',data=car,hue='Origin')

# %%
sn.boxplot(car['Cylinders'])

# %%
plt.figure(figsize=(10,5))
sn.distplot(car['MPG'],kde=True,color='black')

# %%
plt.figure(figsize=(10,5))
sn.boxplot(car['MPG'])

# %%
plt.figure(figsize=(10,5))
sn.distplot(car['Horsepower'],kde=True,color='orange')

# %%
plt.figure(figsize=(10,5))
sn.boxplot(car['Horsepower'])

# %%
plt.figure(figsize=(10,5))
sn.distplot(car['Acceleration'],kde=True,color='blue')

# %%
plt.figure(figsize=(10,5))
sn.boxplot(car['Acceleration'])

# %%
plt.figure(figsize=(10,5))
sn.distplot(car['Displacement'],kde=True,color='brown')

# %%
plt.figure(figsize=(10,5))
plt.boxplot(car['Displacement'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c1d3d9e348>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c1d3d9ec08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2c1d3c77988>],
#  'medians': [<matplotlib.lines.Line2D at 0x2c1d3da4b88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2c1d3da9a08>],
#  'means': []}

# %%
sn.jointplot(x="Cylinders",y="Acceleration",data=car,color='green')

# %%
sn.lmplot('Acceleration', 'Cylinders', data=car, hue='Origin')

# %%
sn.jointplot(x="Horsepower",y="Acceleration",data=car,color='red')

# %%
sn.lmplot('Acceleration', 'Horsepower', data=car, hue='Origin')

# %%
sn.jointplot(x="Model",y="Acceleration",data=car,color='brown')

# %%
sn.lmplot('Acceleration', 'Model', data=car, hue='Origin')

# %%
sn.jointplot(x="Displacement",y="Acceleration",data=car,color='blue')

# %%
sn.lmplot('Acceleration', 'Displacement', data=car, hue='Origin')

# %%
sn.jointplot(x="Weight",y="Acceleration",data=car,color='black')

# %%
sn.lmplot('Acceleration', 'Weight', data=car, hue='Origin')

# %%
sn.jointplot(x="MPG",y="Acceleration",data=car,color='purple')

# %%
sn.lmplot('Acceleration', 'MPG', data=car, hue='Origin')

# %%
sn.jointplot(y="Cylinders",x="Displacement",data=car,color='grey')

# %%
sn.lmplot('Cylinders', 'Displacement', data=car, hue='Origin')

# %%
sn.jointplot(x="Displacement",y="MPG",data=car,color='green')

# %%
sn.lmplot('MPG','Displacement',data=car,hue='Origin')

# %%
sn.jointplot(x="Displacement",y="Horsepower",data=car,color='red')
sn.lmplot('Horsepower','Displacement',data=car,hue='Origin')

# %%
sn.jointplot(x="Displacement",y="Weight",data=car,color='black')
sn.lmplot('Weight','Displacement',data=car,hue='Origin')

# %%
sn.jointplot(x="Displacement",y="Model",data=car,color='brown')
sn.lmplot('Displacement','Model',data=car,hue='Origin')

# %%
car.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.735563     -0.764277   -0.726670 -0.787510
# Cylinders    -0.735563   1.000000      0.951787    0.823467  0.895220
# Displacement -0.764277   0.951787      1.000000    0.873758  0.932475
# Horsepower   -0.726670   0.823467      0.873758    1.000000  0.840811
# Weight       -0.787510   0.895220      0.932475    0.840811  1.000000
# Acceleration  0.424490  -0.522452     -0.557984   -0.682047 -0.430086
# Model         0.586234  -0.360762     -0.381714   -0.419929 -0.315389
#
#               Acceleration     Model
# MPG               0.424490  0.586234
# Cylinders        -0.522452 -0.360762
# Displacement     -0.557984 -0.381714
# Horsepower       -0.682047 -0.419929
# Weight           -0.430086 -0.315389
# Acceleration      1.000000  0.301992
# Model             0.301992  1.000000

# %%
le=preprocessing.LabelEncoder()
car['Origin']=le.fit_transform(car['Origin'])

# %%
car
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1            Buick Skylark 320  15.0          8         350.0       165.0
# 2           Plymouth Satellite  18.0          8         318.0       150.0
# 3                AMC Rebel SST  16.0          8         304.0       150.0
# 4                  Ford Torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0          4         140.0        86.0
# 402          Volkswagen Pickup  44.0          4          97.0        52.0
# 403              Dodge Rampage  32.0          4         135.0        84.0
# 404                Ford Ranger  28.0          4         120.0        79.0
# 405                 Chevy S-10  31.0          4         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
car.corr()
# Out:
#                    MPG  Cylinders  Displacement  Horsepower    Weight  \
# MPG           1.000000  -0.735563     -0.764277   -0.726670 -0.787510
# Cylinders    -0.735563   1.000000      0.951787    0.823467  0.895220
# Displacement -0.764277   0.951787      1.000000    0.873758  0.932475
# Horsepower   -0.726670   0.823467      0.873758    1.000000  0.840811
# Weight       -0.787510   0.895220      0.932475    0.840811  1.000000
# Acceleration  0.424490  -0.522452     -0.557984   -0.682047 -0.430086
# Model         0.586234  -0.360762     -0.381714   -0.419929 -0.315389
# Origin       -0.423525   0.558388      0.595359    0.428593  0.522931
#
#               Acceleration     Model    Origin
# MPG               0.424490  0.586234 -0.423525
# Cylinders        -0.522452 -0.360762  0.558388
# Displacement     -0.557984 -0.381714  0.595359
# Horsepower       -0.682047 -0.419929  0.428593
# Weight           -0.430086 -0.315389  0.522931
# Acceleration      1.000000  0.301992 -0.272942
# ...

# %%
car.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
car.Car.unique()
# Out:
# array(['Chevrolet Chevelle Malibu', 'Buick Skylark 320',
#        'Plymouth Satellite', 'AMC Rebel SST', 'Ford Torino',
#        'Ford Galaxie 500', 'Chevrolet Impala', 'Plymouth Fury iii',
#        'Pontiac Catalina', 'AMC Ambassador DPL', 'Citroen DS-21 Pallas',
#        'Chevrolet Chevelle Concours (sw)', 'Ford Torino (sw)',
#        'Plymouth Satellite (sw)', 'AMC Rebel SST (sw)',
#        'Dodge Challenger SE', "Plymouth 'Cuda 340",
#        'Ford Mustang Boss 302', 'Chevrolet Monte Carlo',
#        'Buick Estate Wagon (sw)', 'Toyota Corolla Mark ii',
#        'Plymouth Duster', 'AMC Hornet', 'Ford Maverick', 'Datsun PL510',
#        'Volkswagen 1131 Deluxe Sedan', 'Peugeot 504', 'Audi 100 LS',
#        'Saab 99e', 'BMW 2002', 'AMC Gremlin', 'Ford F250', 'Chevy C20',
#        'Dodge D200', 'Hi 1200D', 'Chevrolet Vega 2300', 'Toyota Corolla',
#        'Ford Pinto', 'Volkswagen Super Beetle 117',
#        'Plymouth Satellite Custom', 'Ford Torino 500', 'AMC Matador',
# ...

# %%
car.Car.nunique()
# Out:
# 308

# %%
car['Car']=le.fit_transform(car['Car'])

# %%
car
# Out:
#      Car   MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0     50  18.0          8         307.0       130.0  3504.0          12.0
# 1     37  15.0          8         350.0       165.0  3693.0          11.5
# 2    235  18.0          8         318.0       150.0  3436.0          11.0
# 3     14  16.0          8         304.0       150.0  3433.0          12.0
# 4    164  17.0          8         302.0       140.0  3449.0          10.5
# ..   ...   ...        ...           ...         ...     ...           ...
# 401  156  27.0          4         140.0        86.0  2790.0          15.6
# 402  292  44.0          4          97.0        52.0  2130.0          24.6
# 403  121  32.0          4         135.0        84.0  2295.0          11.6
# 404  162  28.0          4         120.0        79.0  2625.0          18.6
# 405   70  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model  Origin
# 0       70       2
# 1       70       2
# ...

# %%
car.corr()
# Out:
#                    Car       MPG  Cylinders  Displacement  Horsepower  \
# Car           1.000000  0.243783  -0.279451     -0.295138   -0.232636
# MPG           0.243783  1.000000  -0.735563     -0.764277   -0.726670
# Cylinders    -0.279451 -0.735563   1.000000      0.951787    0.823467
# Displacement -0.295138 -0.764277   0.951787      1.000000    0.873758
# Horsepower   -0.232636 -0.726670   0.823467      0.873758    1.000000
# Weight       -0.259742 -0.787510   0.895220      0.932475    0.840811
# Acceleration  0.132921  0.424490  -0.522452     -0.557984   -0.682047
# Model         0.078886  0.586234  -0.360762     -0.381714   -0.419929
# Origin       -0.436993 -0.423525   0.558388      0.595359    0.428593
#
#                 Weight  Acceleration     Model    Origin
# Car          -0.259742      0.132921  0.078886 -0.436993
# MPG          -0.787510      0.424490  0.586234 -0.423525
# Cylinders     0.895220     -0.522452 -0.360762  0.558388
# ...

# %%
plt.figure(figsize=(10,6))
sn.heatmap(car.corr())
